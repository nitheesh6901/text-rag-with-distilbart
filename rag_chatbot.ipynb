# %%
# !pip install PyPDF2 sentence-transformers faiss-cpu transformers torch
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: PyPDF2 in c:\users\nithe\appdata\roaming\python\python312\site-packages (3.0.1)
# Requirement already satisfied: sentence-transformers in c:\users\nithe\appdata\roaming\python\python312\site-packages (5.1.1)
# Requirement already satisfied: faiss-cpu in c:\users\nithe\appdata\roaming\python\python312\site-packages (1.12.0)
# Requirement already satisfied: transformers in c:\users\nithe\appdata\roaming\python\python312\site-packages (4.57.1)
# Requirement already satisfied: torch in c:\users\nithe\appdata\roaming\python\python312\site-packages (2.9.0)
# Requirement already satisfied: tqdm in c:\users\nithe\appdata\roaming\python\python312\site-packages (from sentence-transformers) (4.67.1)
# Requirement already satisfied: scikit-learn in c:\users\nithe\appdata\roaming\python\python312\site-packages (from sentence-transformers) (1.7.1)
# Requirement already satisfied: scipy in c:\users\nithe\appdata\roaming\python\python312\site-packages (from sentence-transformers) (1.16.0)
# Requirement already satisfied: huggingface-hub>=0.20.0 in c:\users\nithe\appdata\roaming\python\python312\site-packages (from sentence-transformers) (0.34.4)
# Requirement already satisfied: Pillow in c:\users\nithe\appdata\roaming\python\python312\site-packages (from sentence-transformers) (11.1.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in c:\users\nithe\appdata\roaming\python\python312\site-packages (from sentence-transformers) (4.15.0)
# Requirement already satisfied: filelock in c:\users\nithe\appdata\roaming\python\python312\site-packages (from transformers) (3.16.1)
# Requirement already satisfied: numpy>=1.17 in c:\users\nithe\appdata\roaming\python\python312\site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\nithe\appdata\roaming\python\python312\site-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\nithe\appdata\roaming\python\python312\site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\nithe\appdata\roaming\python\python312\site-packages (from transformers) (2025.7.34)
# Requirement already satisfied: requests in c:\users\nithe\appdata\roaming\python\python312\site-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\users\nithe\appdata\roaming\python\python312\site-packages (from transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\nithe\appdata\roaming\python\python312\site-packages (from transformers) (0.6.2)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\nithe\appdata\roaming\python\python312\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2025.7.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\nithe\appdata\roaming\python\python312\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\nithe\appdata\roaming\python\python312\site-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in c:\users\nithe\appdata\roaming\python\python312\site-packages (from torch) (3.1.4)
# Requirement already satisfied: setuptools in c:\users\nithe\appdata\roaming\python\python312\site-packages (from torch) (75.6.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\nithe\appdata\roaming\python\python312\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: colorama in c:\users\nithe\appdata\roaming\python\python312\site-packages (from tqdm->sentence-transformers) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\nithe\appdata\roaming\python\python312\site-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\nithe\appdata\roaming\python\python312\site-packages (from requests->transformers) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\nithe\appdata\roaming\python\python312\site-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\nithe\appdata\roaming\python\python312\site-packages (from requests->transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\nithe\appdata\roaming\python\python312\site-packages (from requests->transformers) (2024.8.30)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\nithe\appdata\roaming\python\python312\site-packages (from scikit-learn->sentence-transformers) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\nithe\appdata\roaming\python\python312\site-packages (from scikit-learn->sentence-transformers) (3.6.0)
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: C:\Program Files\Python312\python.exe -m pip install --upgrade pip

# %%
from PyPDF2 import PdfReader

# %%
def extract_text_from_pdf(pdf_path):                                                           #Extract text from pdf
  reader = PdfReader(pdf_path)
  text = ""
  for page in reader.pages:
    text +=page.extract_text() + "\n"
  return text

# %%
def chunk_text(text,chunk_size=300):                                                          # splits text into chunks
  words = text.split()
  return [" ".join(words[i:i+chunk_size]) for i in range (0,len(words),chunk_size)]

# %%
from sentence_transformers import SentenceTransformer
# Out:
# WARNING:tensorflow:From C:\Users\nithe\AppData\Roaming\Python\Python312\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
import faiss

# %%
def create_faiss_index(chunks,model):                                                          # creating embeddings and faiss index
  embeddings = model.encode(chunks,convert_to_numpy=True,show_progress_bar=True)
  dim = embeddings.shape[1]
  index = faiss.IndexFlatIP(dim)  

  index.add(embeddings)
  return index,embeddings

# %%
def search_faiss(query,model,index,chunks,top_k=3):                             # Searches for the most relevant text chunks to the query using FAISS
  query_emb = model.encode([query],convert_to_numpy=True)
  distances,indices = index.search(query_emb,top_k)
  results = [chunks[i] for i in indices[0]]
  return results

# %%
from transformers import pipeline

# %%
summarizer = pipeline("summarization",model="sshleifer/distilbart-cnn-12-6")           # Load a pre-trained summarization model (DistilBART)
# Out:
# Device set to use cpu

# %%
def summarize_text(text):
  return summarizer(text,max_length=100,min_length=30,do_sample=False)[0]["summary_text"]

# %%
def rag_bot(pdf_path,query):                                                             #Combine everything into a chatbot
  print("extracting text...")
  text = extract_text_from_pdf(pdf_path)                                                 # extract text      

  print("chunking text....")                                                             #chunk text
  chunks = chunk_text(text)

  print("creating embeddings....")                                                       # Generate embeddings and create FAISS index
  model = SentenceTransformer("sentence-transformers/paraphrase-MiniLM-L6-v2")
  index,embeddings=create_faiss_index(chunks,model)

  print("searching for relevant chunks...")                                              # Search for relevant chunks
  top_chunks = search_faiss(query,model,index,chunks)

  print("summarizing answer....")                                                        # Summarize top chunks into a concise answer
  combined_text = "".join(top_chunks)
  summary = summarize_text(combined_text)
  return summary,top_chunks

# %%
pdf_path = "small_helmet.pdf"
query = "What are the safety features of the helmet?"                                    # User query

                                                                                         # Run the chatbot and get answer and reference chunks
answer, refs = rag_bot(pdf_path, query)

                                                                                         # Display the final summarized answer
print("\n Final Answer:\n", answer)

                                                                                         # Display the top chunks used for reference
print("\n References:")
for i, ref in enumerate(refs, 1):
    print(f"{i}. {ref[:200]}...")
# Out:
# extracting text...
# chunking text....
# creating embeddings....
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# searching for relevant chunks...
# summarizing answer....
#
#  Final Answer:
#   Smart Safety Helmet features real-time fall detection, heart rate monitoring and GPS tracking for location . This helmet ensures maximum protection for bikers on the road .
#
#  References:
# 1. Smart Safety Helmet Features: 1. Real-time fall detection. 2. Heart rate monitoring. 3. GPS tracking for location. 4. Emergency alerts to contacts. 5. Built-in voice assistance. This helmet ensures ma...
# 2. Smart Safety Helmet Features: 1. Real-time fall detection. 2. Heart rate monitoring. 3. GPS tracking for location. 4. Emergency alerts to contacts. 5. Built-in voice assistance. This helmet ensures ma...
# 3. Smart Safety Helmet Features: 1. Real-time fall detection. 2. Heart rate monitoring. 3. GPS tracking for location. 4. Emergency alerts to contacts. 5. Built-in voice assistance. This helmet ensures ma...
